# %%
# Import Required Librbary
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# %%
raw_data = pd.read_excel('Raw Data.xlsx')

# %%
column_order = ["Index", "Memo No Usage", "District", "PRN No", "Occupation Date", "Building Name", "Address", "PASP", "Ins. Date", "Floor", "Unit", "Area", "Area(N)(ft2)", "Headroom View", "View", "Price(M)($)", "Price($)", "$/ft2(N)($)", "Nature", "Bldg Remarks", "Trans Remark", "Unit Rate"]

# %%
Area = []
Price = []
for record in raw_data["Area(N)(ft2)"]:
    Area.append(record / 10.7590132827)

for record in raw_data["Price(M)($)"]:
    Price.append(record * pow(10, 6))
# Out:
# [11300000.0, 10820000.0, 10820000.0, 7950000.0, 7900000.0, 7900000.0, 8000000.0, 5350000.0, 9980000.0, 9560000.0, 9750000.0, 8688000.0, 8154000.0, 8918000.0, 9138000.0, 9560000.0, 9980000.0, 9372000.0, 10000000.0, 10820000.0, 10820000.0, 11300000.0, 10000000.0, 8970000.0, 10820000.0, 11300000.0, 7220000.0, 7280000.0, 8438000.0, 8400000.0, 5490000.0, 5330000.0, 5205000.0, 5205000.0, 5450000.0, 5500000.0, 4730000.0, 7280000.0, 7220000.0, 7220000.0, 7680000.0, 5190000.0, 5190000.0, 4260000.0, 4000000.0, 7220000.0, 7280000.0, 7230000.0, 8438000.0, 7638000.0, 5880000.0, 8300000.000000001, 5350000.0, 5200000.0, 5280000.0, 7280000.0, 8438000.0, 4130000.0, 4950000.0, 7280000.0, 8438000.0, 8438000.0, 7280000.0, 7230000.0, 7750000.0, 7800000.0, 6000000.0, 5838000.0, 5600000.0, 5460000.0, 5380000.0, 7950000.0, 5585000.0, 7750000.0, 10820000.0, 5680000.0, 5550000.0, 5550000.0, 5500000.0, 5300000.0, 5350000.0, 7800000.0, 11300000.0, 7638000.0, 7230000.0, 12355000.0, 16379999.999999998, 16379999.9
# ...
